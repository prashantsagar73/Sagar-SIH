# %%
import pandas as pd

# %% [markdown]
# # index  drop,remove & edit

# %%
bond=pd.read_csv('/Users/prashantsagar/Desktop/Data analysis/csvfile/jamesbond.csv')
bond.head(9)
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 1            From Russia with Love  1963    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
# 8                 Live and Let Die  1973     Roger Moore   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# ...

# %%
bond.set_index("Film").head(3)
# for seting any col.  to index
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(drop= False)
bond.reset_index(drop= True, inplace=True)
# for reseting the index like before

# %%
bond.head(4)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7

# %%
bond.set_index('Film',inplace=True)
bond.short_index= True

# %%
bond.head(8)
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# ...

# %% [markdown]
# # loc[ ]  method

# %%
bond.loc["Goldfinger":"Diamonds Are Forever":2]
# it return the values from given parameter in interval of 2
# Out:
#                                  Year           Actor       Director  \
# Film
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Casino Royale                    1967     David Niven     Ken Hughes
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Goldfinger                            820.4    18.6                3.2
# Casino Royale                         315.0    85.0                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.loc["Goldfinger"]
# it give details about give data
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc["Goldfinger":]
# bond.loc[:"Goldfinger"]


# it give all the vlaue fom given parameter to  last
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.loc[["Goldfinger","Diamonds Are Forever"]]
# Out:
#                       Year         Actor      Director  Box Office  Budget  \
# Film
# Goldfinger            1964  Sean Connery  Guy Hamilton       820.4    18.6
# Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# Goldfinger                          3.2
# Diamonds Are Forever                5.8

# %%
"Diamonds Are Forever"in bond.index
# it give the boolean value if it contain in list
# Out:
# True

# %% [markdown]
# # iloc[ ] method
# ## similar to loc fintion but it take int value  only

# %%
bond=pd.read_csv('/Users/prashantsagar/Desktop/Data analysis/csvfile/jamesbond.csv')
# bond.set_index("Film",inplace=True)
# bond.sort_index(True,inplace= True)
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.iloc[2]
# Out:
# Film                   Goldfinger
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: 2, dtype: object

# %%
bond.iloc[4:]
# Out:
#                                  Year           Actor            Director  \
# Film
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# ...

# %%
# bond.set_index("Film",inplace=True)
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[[0,4,3]]
# Out:
#                       Year           Actor      Director  Box Office  Budget  \
# Film
# A View to a Kill      1985     Roger Moore     John Glen       275.2    54.5
# Die Another Day       2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
# Diamonds Are Forever  1971    Sean Connery  Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Die Another Day                    17.9
# Diamonds Are Forever                5.8

# %%
bond.loc['Die Another Day', 'Director']
# also call like this
# Out:
# 'Lee Tamahori'

# %%
bond.loc['Die Another Day',['Actor','Budget']]
# Out:
# Actor     Pierce Brosnan
# Budget             154.2
# Name: Die Another Day, dtype: object

# %%
bond.loc['Die Another Day':,'Actor':'Box Office']
bond.loc[:'GoldenEye','Actor':]
# Out:
#                                 Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill          Roger Moore        John Glen       275.2    54.5
# Casino Royale            Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale             David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever     Sean Connery     Guy Hamilton       442.5    34.7
# Die Another Day        Pierce Brosnan     Lee Tamahori       465.4   154.2
# Dr. No                   Sean Connery    Terence Young       448.8     7.0
# For Your Eyes Only        Roger Moore        John Glen       449.4    60.2
# From Russia with Love    Sean Connery    Terence Young       543.8    12.6
# GoldenEye              Pierce Brosnan  Martin Campbell       518.5    76.9
#
#                        Bond Actor Salary
# Film
# A View to a Kill                     9.1
# Casino Royale                        3.3
# Casino Royale                        NaN
# ...

# %%
bond.iloc[[3,5],:3]
bond.iloc[[4,5,7,8],2:]
bond.iloc[2:,[2,4]]
# Out:
#                                            Director  Budget
# Film
# Casino Royale                            Ken Hughes    85.0
# Diamonds Are Forever                   Guy Hamilton    34.7
# Die Another Day                        Lee Tamahori   154.2
# Dr. No                                Terence Young     7.0
# For Your Eyes Only                        John Glen    60.2
# From Russia with Love                 Terence Young    12.6
# GoldenEye                           Martin Campbell    76.9
# Goldfinger                             Guy Hamilton    18.6
# Licence to Kill                           John Glen    56.7
# Live and Let Die                       Guy Hamilton    30.8
# Moonraker                             Lewis Gilbert    91.5
# Never Say Never Again                Irvin Kershner    86.0
# Octopussy                                 John Glen    53.9
# On Her Majesty's Secret Service       Peter R. Hunt    37.3
# Quantum of Solace                      Marc Forster   181.4
# ...

# %%
bond.loc['GoldenEye','Actor']="prashant"
# assign the new value

# %%
bond.loc['GoldenEye','Actor']
# Out:
# 'prashant'

# %% [markdown]
# # rename method

# %%
bond.rename(index={'goldenfinger':'Goldenfinger','Licence to kill':'licence to kill'})
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995        prashant     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.head(2)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3

# %%
bond.rename(mapper={"Year": "Realesed year","Bond Actor Salary":"Actor Salary"},axis=1).head()
# Out:
#                       Realesed year           Actor         Director  \
# Film
# A View to a Kill               1985     Roger Moore        John Glen
# Casino Royale                  2006    Daniel Craig  Martin Campbell
# Casino Royale                  1967     David Niven       Ken Hughes
# Diamonds Are Forever           1971    Sean Connery     Guy Hamilton
# Die Another Day                2002  Pierce Brosnan     Lee Tamahori
#
#                       Box Office  Budget  Actor Salary
# Film
# A View to a Kill           275.2    54.5           9.1
# Casino Royale              581.5   145.3           3.3
# Casino Royale              315.0    85.0           NaN
# Diamonds Are Forever       442.5    34.7           5.8
# Die Another Day            465.4   154.2          17.9

# %%
bond.rename(columns={"Year": "Realesed_year","Bond Actor Salary":"Actor Salary"},inplace= True)

# %%
bond.head()
# Out:
#                     Film              Realesed_year         Actor  \
# 0                 Dr. No  1962MILLIONMILLIONMILLION  Sean Connery
# 1  From Russia with Love  1963MILLIONMILLIONMILLION  Sean Connery
# 2             Goldfinger  1964MILLIONMILLIONMILLION  Sean Connery
# 3            Thunderball  1965MILLIONMILLIONMILLION  Sean Connery
# 4          Casino Royale  1967MILLIONMILLIONMILLION   David Niven
#
#         Director    Box Office       Budget  Actor Salary
# 0  Terence Young  448.8MILLION   7.0MILLION           0.6
# 1  Terence Young  543.8MILLION  12.6MILLION           1.6
# 2   Guy Hamilton  820.4MILLION  18.6MILLION           3.2
# 3  Terence Young  848.1MILLION  41.9MILLION           4.7
# 4     Ken Hughes  315.0MILLION  85.0MILLION           NaN

# %%
bond.columns
# Out:
# Index(['Film', 'Realesed_year', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Actor Salary'],
#       dtype='object')

# %%
bond.columns=['year','Actor','Director','Box office','Budget','Salary']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f4608b09a79c> in <module>
# ----> 1 bond.columns=['year','Actor','Director','Box office','Budget','Salary']
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# ...

# %%
bond.head(3)
# Out:
#                   year         Actor         Director  Box office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Salary
# Film
# A View to a Kill     9.1
# Casino Royale        3.3
# Casino Royale        NaN

# %% [markdown]
# # drop & pull method

# %%
bond.drop('Actor',axis="columns").head()
# Out:
#                       year         Director  Box office  Budget  Salary
# Film
# A View to a Kill      1985        John Glen       275.2    54.5     9.1
# Casino Royale         2006  Martin Campbell       581.5   145.3     3.3
# Casino Royale         1967       Ken Hughes       315.0    85.0     NaN
# Diamonds Are Forever  1971     Guy Hamilton       442.5    34.7     5.8
# Die Another Day       2002     Lee Tamahori       465.4   154.2    17.9

# %%
bond.drop("Casino Royale").head()
# Out:
#                       year           Actor       Director  Box office  Budget  \
# Film
# A View to a Kill      1985     Roger Moore      John Glen       275.2    54.5
# Diamonds Are Forever  1971    Sean Connery   Guy Hamilton       442.5    34.7
# Die Another Day       2002  Pierce Brosnan   Lee Tamahori       465.4   154.2
# Dr. No                1962    Sean Connery  Terence Young       448.8     7.0
# For Your Eyes Only    1981     Roger Moore      John Glen       449.4    60.2
#
#                       Salary
# Film
# A View to a Kill         9.1
# Diamonds Are Forever     5.8
# Die Another Day         17.9
# Dr. No                   0.6
# For Your Eyes Only       NaN

# %% [markdown]
# # sample method

# %%
bond.sample()
# it would be random
# Out:
#                year         Actor         Director  Box office  Budget  Salary
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3     3.3

# %%
bond.sample(n=3)
# Out:
#                       year           Actor       Director  Box office  Budget  \
# Film
# Moonraker             1979     Roger Moore  Lewis Gilbert       535.0    91.5
# A View to a Kill      1985     Roger Moore      John Glen       275.2    54.5
# The Living Daylights  1987  Timothy Dalton      John Glen       313.5    68.8
#
#                       Salary
# Film
# Moonraker                NaN
# A View to a Kill         9.1
# The Living Daylights     5.2

# %%
bond.sample(frac=.25)
# it return the 25% of my list
# Out:
#                       year           Actor            Director  Box office  \
# Film
# Casino Royale         1967     David Niven          Ken Hughes       315.0
# You Only Live Twice   1967    Sean Connery       Lewis Gilbert       514.2
# Tomorrow Never Dies   1997  Pierce Brosnan  Roger Spottiswoode       463.2
# Dr. No                1962    Sean Connery       Terence Young       448.8
# Casino Royale         2006    Daniel Craig     Martin Campbell       581.5
# Diamonds Are Forever  1971    Sean Connery        Guy Hamilton       442.5
#
#                       Budget  Salary
# Film
# Casino Royale           85.0     NaN
# You Only Live Twice     59.9     4.4
# Tomorrow Never Dies    133.9    10.0
# Dr. No                   7.0     0.6
# Casino Royale          145.3     3.3
# Diamonds Are Forever    34.7     5.8

# %% [markdown]
# # nsmallest & nlargest method

# %%
bond.nsmallest(n=3,columns="Salary")
# ir return the largest vlaues from salary column
# Out:
#                                  year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# From Russia with Love            1963    Sean Connery  Terence Young
#
#                                  Box office  Budget  Salary
# Film
# Dr. No                                448.8     7.0     0.6
# On Her Majesty's Secret Service       291.5    37.3     0.6
# From Russia with Love                 543.8    12.6     1.6

# %%
bond.nlargest(n=3,columns='Box office')
# Out:
#              year         Actor       Director  Box office  Budget  Salary
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2    14.5
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9     4.7
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6     3.2

# %% [markdown]
# # filtering with where method

# %%
bond.where(bond['Budget']>150)
# Out:
#                                    year           Actor       Director  \
# Film
# A View to a Kill                    NaN             NaN            NaN
# Casino Royale                       NaN             NaN            NaN
# Casino Royale                       NaN             NaN            NaN
# Diamonds Are Forever                NaN             NaN            NaN
# Die Another Day                  2002.0  Pierce Brosnan   Lee Tamahori
# Dr. No                              NaN             NaN            NaN
# For Your Eyes Only                  NaN             NaN            NaN
# From Russia with Love               NaN             NaN            NaN
# GoldenEye                           NaN             NaN            NaN
# Goldfinger                          NaN             NaN            NaN
# Licence to Kill                     NaN             NaN            NaN
# Live and Let Die                    NaN             NaN            NaN
# ...

# %% [markdown]
# # query method

# %%
bond.query("Actor =='David Niven'")
# Out:
#                year        Actor    Director  Box office  Budget  Salary
# Film
# Casino Royale  1967  David Niven  Ken Hughes       315.0    85.0     NaN

# %%
bond.query("Actor !='David Niven'")
# Out:
#                                  year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995        prashant     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.query("Actor == 'Sean Connery' and Director == 'Guy Hamilton'")
# insted of and we use   or    too
# Out:
#                       year         Actor      Director  Box office  Budget  \
# Film
# Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
# Goldfinger            1964  Sean Connery  Guy Hamilton       820.4    18.6
#
#                       Salary
# Film
# Diamonds Are Forever     5.8
# Goldfinger               3.2

# %% [markdown]
# # apply method

# %%
def str_to_million(number):
    return str(number) + "MILLION"

# %%
columns=["Realesed_year","Box Office","Budget","Realesed_year"]
for col in columns:
       bond[col]= bond[col].apply(str_to_million)

# %%
bond.sample(n=3)
# Out:
#                     Film                                   Realesed_year  \
# 10  The Spy Who Loved Me  1977MILLIONMILLIONMILLIONMILLIONMILLIONMILLION
# 19   Tomorrow Never Dies  1997MILLIONMILLIONMILLIONMILLIONMILLIONMILLION
# 24               Skyfall  2012MILLIONMILLIONMILLIONMILLIONMILLIONMILLION
#
#              Actor            Director                  Box Office  \
# 10     Roger Moore       Lewis Gilbert  533.0MILLIONMILLIONMILLION
# 19  Pierce Brosnan  Roger Spottiswoode  463.2MILLIONMILLIONMILLION
# 24    Daniel Craig          Sam Mendes  943.5MILLIONMILLIONMILLION
#
#                         Budget  Actor Salary
# 10   45.1MILLIONMILLIONMILLION           NaN
# 19  133.9MILLIONMILLIONMILLION          10.0
# 24  170.2MILLIONMILLIONMILLION          14.5

# %%
bond=pd.read_csv('/Users/prashantsagar/Desktop/Data analysis/csvfile/jamesbond.csv')
bond.head(9)
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 1            From Russia with Love  1963    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
# 8                 Live and Let Die  1973     Roger Moore   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# ...

# %% [markdown]
# # copy method

# %%
directors=bond['Director'].copy()
directors.head(3)
# Out:
# 0    Terence Young
# 1    Terence Young
# 2     Guy Hamilton
# Name: Director, dtype: object

# %%
directors[2]= "prashant"

# %%
directors.head(4)
# Out:
# 0    Terence Young
# 1    Terence Young
# 2         prashant
# 3    Terence Young
# Name: Director, dtype: object
